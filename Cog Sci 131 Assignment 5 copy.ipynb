# %%
# %matplotlib inline
import random
import numpy as np
import matplotlib.pyplot as plt

# %%
#Question 1

# %%
#Question 2

#stress = np.array([i, j])

#def distance(i, j):
#    np.sqrt((i - 0)**2 + (j - 0)**2)

#def stress(vector):
    
#    i = sy.Symbol('i')
#    j = sy.Symbol('j')
#    sy.summation((psi - distance(i, j))**2)

names = ["football", "baseball", "basketball", "tennis", "softball", "canoeing", "handball", "rugby", "hockey", "ice hockey", "swimming", "track", "boxing", "volleyball", "lacrosse", "skiing", "golf", "polo", "surfing", "wrestling", "gymnastics"]         
similarities = np.loadtxt(open("Assignment5-similarities.csv", "rb"), delimiter = ",", skiprows = 1)
         
distances = 1 - similarities
dimensions = 2
items = distances.shape[0]
         
assert(distances.shape[1] == items and items == len(names))
position = np.random.normal(0.0, 1.0, size = (items, dimensions))

def distance(x, y):
    return np.linalg.norm(x-y)
         
def stress(p): 
    stress_list = []
    for i in range(0, 21):
        for j in range(0, 21): 
            if i > j:
                stress_list.append((distances[i, j] - distance(np.array([p[i, 0], p[i, 1]]), np.array([p[j,0], p[j,1]])))**2)
    return np.sum(stress_list) 
stress(position)
# Out:
# 530.413683470188

# %%
#Question 3

#delta = 0.001
#def gradience(p, delta):
#    df = (stress(p+delta) - stress(p-delta))/2*delta
     
#for i in range(len(vector)):
#    gradient = gradience(p, delta)
    
def delta_helper(p, q, r, delta): 
    vector = np.array(p)
    vector[q, r] += delta 
    return vector

def gradient(p, q, r, delta = 0.001):
    x = ((stress(delta_helper(p, q, r, delta)) - stress(delta_helper(p, q, r, -delta)))/(2*delta)) 
    return x

def full_gradient(p):
    matrix = np.zeros([items, dimensions]) 
    for q in range(0, items):
        for r in range(0, dimensions):
            matrix[q][r] = gradient(p, q, r, delta = 0.001)
    return matrix

def steps(p):
    for steps in range(100):
        p -= full_gradient(p)*0.001 
    return p

# %%
#Question 4

def sport_stress(values): 
    i=0
    while i != 21:
        x = values[i][0]
        y = values[i][1]
        plt.scatter(x,y)
        plt.text(x, y, names[i])
        i += 1
    return plt.show()

new_values = full_gradient(position) 
sport_stress(new_values)

# %%
#Question 5

MDS = []
psychological = [] 
calculation = steps(position)

for i in range(21): 
    for j in range(21):
        if i != d: 
            psychological.append(distances[i,j]) 
            position1 = np.array([calculation[i,0], calculation[i,1]]) 
            position2 = np.array([calculation[j,0], calculation[j, 1]]) 
            position3 = distance(position1, position2) 
            MDS.append(position3)
plt.scatter(psychological, MDS)
plt.show()

# %%
#Question 6

position = np.random.normal(0.0, 1.0, size = (items, dimensions)) 
x,y = [],[]

for i in range(1000):
    x.append(i)
    position -= full_gradient(position)*0.001
    y.append(stress(position))
plt.plot(x,y)
plt.show()

# %%
#Question 7
#Trial 1

for i in range(10):
    position = np.random.normal(0.0, 1.0, size = (items, dimensions)) 
    def sport_trials(values):
        i=0
        while i != 21:
            x = values[i][0]
            y = values[i][1]
            plt.scatter(x,y)
            plt.text(x, y, names[i])
            i += 1
        return plt.show() 
new_values = full_gradient(position) 
print(stress(new_values))

sport_trials(new_values) 
plt.show()
# Out:
# 775558.4321098025

# %%
#Trial 2

for i in range(10):
    position = np.random.normal(0.0, 1.0, size = (items, dimensions)) 
    def sport_trials(values):
        i=0
        while i != 21:
            x = values[i][0]
            y = values[i][1]
            plt.scatter(x,y)
            plt.text(x, y, names[i])
            i += 1
        return plt.show() 
new_values = full_gradient(position) 
print(stress(new_values))

sport_trials(new_values) 
plt.show()
# Out:
# 1031727.9667872983

# %%
#Trial 3

for i in range(10):
    position = np.random.normal(0.0, 1.0, size = (items, dimensions)) 
    def sport_trials(values):
        i=0
        while i != 21:
            x = values[i][0]
            y = values[i][1]
            plt.scatter(x,y)
            plt.text(x, y, names[i])
            i += 1
        return plt.show() 
new_values = full_gradient(position) 
print(stress(new_values))

sport_trials(new_values) 
plt.show()
# Out:
# 508819.2832725117

# %%
#Trial 4

for i in range(10):
    position = np.random.normal(0.0, 1.0, size = (items, dimensions)) 
    def sport_trials(values):
        i=0
        while i != 21:
            x = values[i][0]
            y = values[i][1]
            plt.scatter(x,y)
            plt.text(x, y, names[i])
            i += 1
        return plt.show() 
new_values = full_gradient(position) 
print(stress(new_values))

sport_trials(new_values) 
plt.show()
# Out:
# 577790.2572610304

# %%
#Trial 5

for i in range(10):
    position = np.random.normal(0.0, 1.0, size = (items, dimensions)) 
    def sport_trials(values):
        i=0
        while i != 21:
            x = values[i][0]
            y = values[i][1]
            plt.scatter(x,y)
            plt.text(x, y, names[i])
            i += 1
        return plt.show() 
new_values = full_gradient(position) 
print(stress(new_values))

sport_trials(new_values) 
plt.show()
# Out:
# 1046448.3592934483

# %%
#Trial 6

for i in range(10):
    position = np.random.normal(0.0, 1.0, size = (items, dimensions)) 
    def sport_trials(values):
        i=0
        while i != 21:
            x = values[i][0]
            y = values[i][1]
            plt.scatter(x,y)
            plt.text(x, y, names[i])
            i += 1
        return plt.show() 
new_values = full_gradient(position) 
print(stress(new_values))

sport_trials(new_values) 
plt.show()
# Out:
# 775639.3493961154

# %%
#Trial 7

for i in range(10):
    position = np.random.normal(0.0, 1.0, size = (items, dimensions)) 
    def sport_trials(values):
        i=0
        while i != 21:
            x = values[i][0]
            y = values[i][1]
            plt.scatter(x,y)
            plt.text(x, y, names[i])
            i += 1
        return plt.show() 
new_values = full_gradient(position) 
print(stress(new_values))

sport_trials(new_values) 
plt.show()
# Out:
# 918008.3252238275

# %%
#Trial 8

for i in range(10):
    position = np.random.normal(0.0, 1.0, size = (items, dimensions)) 
    def sport_trials(values):
        i=0
        while i != 21:
            x = values[i][0]
            y = values[i][1]
            plt.scatter(x,y)
            plt.text(x, y, names[i])
            i += 1
        return plt.show() 
new_values = full_gradient(position) 
print(stress(new_values))

sport_trials(new_values) 
plt.show()
# Out:
# 848614.0057785241

# %%
#Trial 9

for i in range(10):
    position = np.random.normal(0.0, 1.0, size = (items, dimensions)) 
    def sport_trials(values):
        i=0
        while i != 21:
            x = values[i][0]
            y = values[i][1]
            plt.scatter(x,y)
            plt.text(x, y, names[i])
            i += 1
        return plt.show() 
new_values = full_gradient(position) 
print(stress(new_values))

sport_trials(new_values) 
plt.show()
# Out:
# 519026.8055229039

# %%
#Trial 10

for i in range(10):
    position = np.random.normal(0.0, 1.0, size = (items, dimensions)) 
    def sport_trials(values):
        i=0
        while i != 21:
            x = values[i][0]
            y = values[i][1]
            plt.scatter(x,y)
            plt.text(x, y, names[i])
            i += 1
        return plt.show() 
new_values = full_gradient(position) 
print(stress(new_values))

sport_trials(new_values) 
plt.show()
# Out:
# 1170687.8659941703

# %%
#Question 8
